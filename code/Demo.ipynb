# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
img1 = plt.imread('../data/Kather_texture_2016_image_tiles_5000/01_TUMOR/10009_CRC-Prim-HE-03_009.tif_Row_301_Col_151.tif')
img2 = plt.imread('../data/Kather_texture_2016_image_tiles_5000/03_COMPLEX/10011_CRC-Prim-HE-03_002.tif_Row_451_Col_901.tif')

# %%
img1.shape
# Out:
# (150, 150, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
import tensorflow_datasets as tfds

# %%
df = tfds.ImageFolder(
    '../data/Kather_texture_2016_image_tiles_5000/')

# %%
print(df.info)
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='../data/Kather_texture_2016_image_tiles_5000/',
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=0),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#     },
#     citation="""""",
# )

# %%
ds = df.as_dataset( shuffle_files=True)
tfds.show_examples(ds,  df.info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xl/mhd952bn1w9cdpylw329ccq40000gn/T/ipykernel_92311/1937347384.py in <module>
#       1 ds = df.as_dataset( shuffle_files=True)
# ----> 2 tfds.show_examples(ds,  df.info)
#
# ~/Python-Environments/tf25/lib/python3.7/site-packages/tensorflow_datasets/core/visualization/show_examples.py in show_examples(ds, ds_info, **options_kwargs)
#      70
#      71   # Pack `as_supervised=True` datasets
# ---> 72   ds = dataset_info.pack_as_supervised_ds(ds, ds_info)
#      73
#      74   for visualizer in _ALL_VISUALIZERS:
#
# ~/Python-Environments/tf25/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_info.py in pack_as_supervised_ds(ds, ds_info)
#     554 ) -> tf.data.Dataset:
#     555   """Pack `(input, label)` dataset as `{'key0': input, 'key1': label}`."""
# ...
